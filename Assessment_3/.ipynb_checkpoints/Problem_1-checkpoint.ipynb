# %% [markdown]
# # Assessed Problem #1

# %%
#Libraries
from numpy             import *
from run_kut4          import *
from matplotlib.pyplot import *
#

#Subroutines
def F(x,f):
    return -w*sin(f) + y*w**2*cos(f)*sin(x)
def G(x,g):
    return g
def H(x,h):
    return -w*sin(h) + y*w**2*cos(h)*sin(x)
#

#Constants
w     = sqrt(9.81/10E-2)
B     = 5/w
y     = 10E-2*2/9.81

g0 = 0
h0 = 0
#

#Computation
X,Y = integrate(G,0,0,40*w,0.1)
plot(X,Y)
show()
X,Y = integrate(H,0,0,40*w,0.1)
plot(X,Y)
show()
#
